# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('P7.csv')
df
# Out:
# D:\Python\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,1,2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         District         Event Circle Police Station Caller Source  \
# 0        LUCKNOW  P01042100004     C1            PS1         PHONE
# 1        LUCKNOW  P01042104316     C1            PS1         PHONE
# 2        LUCKNOW  P01042104847     C1            PS1         PHONE
# 3        LUCKNOW  P01042105074     C1            PS1         PHONE
# 4        LUCKNOW  P01042105152     C1            PS1         PHONE
# ...          ...           ...    ...            ...           ...
# 1016439      NaN           NaN    NaN            NaN           NaN
# 1016440      NaN           NaN    NaN            NaN           NaN
# 1016441      NaN           NaN    NaN            NaN           NaN
# 1016442      NaN           NaN    NaN            NaN           NaN
# 1016443      NaN           NaN    NaN            NaN           NaN
#
#                          Event Type       Event Sub-Type     Create Date/Time  \
# 0        Information Against Police   Misbehavior By Prv  01-04-2021 00:00:00
# 1                  Threat In Person               Attack  01-04-2021 12:09:00
# 2                           Dispute  Dispute In Hospital  01-04-2021 12:51:00
# 3                          Gambling           Play Cards  01-04-2021 13:10:00
# 4                  Threat In Person               Attack  01-04-2021 13:18:00
# ...                             ...                  ...                  ...
# 1016439                         NaN                  NaN                  NaN
# 1016440                         NaN                  NaN                  NaN
# 1016441                         NaN                  NaN                  NaN
# 1016442                         NaN                  NaN                  NaN
# 1016443                         NaN                  NaN                  NaN
#
#          Latitude  Longitude
# 0          26.834     81.008
# 1          26.828     81.014
# 2          26.840     81.009
# 3          26.828     81.002
# 4          26.834     81.033
# ...           ...        ...
# 1016439       NaN        NaN
# 1016440       NaN        NaN
# 1016441       NaN        NaN
# 1016442       NaN        NaN
# 1016443       NaN        NaN
#
# [1016444 rows x 10 columns]

# %%
df_c = df.dropna()
df_c
# Out:
#      District         Event Circle Police Station Caller Source  \
# 0     LUCKNOW  P01042100004     C1            PS1         PHONE
# 1     LUCKNOW  P01042104316     C1            PS1         PHONE
# 2     LUCKNOW  P01042104847     C1            PS1         PHONE
# 3     LUCKNOW  P01042105074     C1            PS1         PHONE
# 4     LUCKNOW  P01042105152     C1            PS1         PHONE
# ...       ...           ...    ...            ...           ...
# 5123  LUCKNOW  P30062111143     C2            PS4         PHONE
# 5124  LUCKNOW  P30062111164     C2            PS4         PHONE
# 5125  LUCKNOW  P30062111341     C2            PS4         PHONE
# 5126  LUCKNOW  P30062111700     C2            PS4         PHONE
# 5127  LUCKNOW  P30062118243     C2            PS4         PHONE
#
#                       Event Type                   Event Sub-Type  \
# 0     Information Against Police               Misbehavior By Prv
# 1               Threat In Person                           Attack
# 2                        Dispute              Dispute In Hospital
# 3                       Gambling                       Play Cards
# 4               Threat In Person                           Attack
# ...                          ...                              ...
# 5123                     Dispute                    With Neighbor
# 5124                     Dispute  Dispute Between Ride And Driver
# 5125                Cyber Crimes             Bank Account Hacking
# 5126                     Robbery                          On Road
# 5127            Threat In Person              Threatening To Kill
#
#          Create Date/Time  Latitude  Longitude
# 0     01-04-2021 00:00:00    26.834     81.008
# 1     01-04-2021 12:09:00    26.828     81.014
# 2     01-04-2021 12:51:00    26.840     81.009
# 3     01-04-2021 13:10:00    26.828     81.002
# 4     01-04-2021 13:18:00    26.834     81.033
# ...                   ...       ...        ...
# 5123  30-06-2021 17:59:54    26.866     81.026
# 5124  30-06-2021 18:01:05    26.864     81.006
# 5125  30-06-2021 18:10:59    26.864     80.998
# 5126  30-06-2021 18:33:39    26.873     81.023
# 5127  30-06-2021 23:59:08    26.863     81.001
#
# [5123 rows x 10 columns]

# %%
# creating a day column which stores date and time in datetime fomat
df_c['day'] =pd.to_datetime(df_c['Create Date/Time'],dayfirst=True)
df_c['day'].head()
# Out:
# <ipython-input-3-b7abf333d369>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['day'] =pd.to_datetime(df_c['Create Date/Time'],dayfirst=True)
# 0   2021-04-01 00:00:00
# 1   2021-04-01 12:09:00
# 2   2021-04-01 12:51:00
# 3   2021-04-01 13:10:00
# 4   2021-04-01 13:18:00
# Name: day, dtype: datetime64[ns]

# %%
# converting to datetime format to hold yearfirst value
# df['prop_date']=pd.to_datetime(df['day']).pd.strftime('%m/%d/%Y')
df_c['day']=pd.to_datetime(df_c['day'],yearfirst=True)
df_c.head()
# Out:
# <ipython-input-4-4729b525a6dc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['day']=pd.to_datetime(df_c['day'],yearfirst=True)
#   District         Event Circle Police Station Caller Source  \
# 0  LUCKNOW  P01042100004     C1            PS1         PHONE
# 1  LUCKNOW  P01042104316     C1            PS1         PHONE
# 2  LUCKNOW  P01042104847     C1            PS1         PHONE
# 3  LUCKNOW  P01042105074     C1            PS1         PHONE
# 4  LUCKNOW  P01042105152     C1            PS1         PHONE
#
#                    Event Type       Event Sub-Type     Create Date/Time  \
# 0  Information Against Police   Misbehavior By Prv  01-04-2021 00:00:00
# 1            Threat In Person               Attack  01-04-2021 12:09:00
# 2                     Dispute  Dispute In Hospital  01-04-2021 12:51:00
# 3                    Gambling           Play Cards  01-04-2021 13:10:00
# 4            Threat In Person               Attack  01-04-2021 13:18:00
#
#    Latitude  Longitude                 day
# 0    26.834     81.008 2021-04-01 00:00:00
# 1    26.828     81.014 2021-04-01 12:09:00
# 2    26.840     81.009 2021-04-01 12:51:00
# 3    26.828     81.002 2021-04-01 13:10:00
# 4    26.834     81.033 2021-04-01 13:18:00

# %%
# getting the time from the date time we've been given 
new_df = pd.read_csv('P7.csv')
new_df.dropna(inplace=True)
df_c['Create Date/Time']=new_df['Create Date/Time']
df_c['Time']=pd.to_datetime(df_c['Create Date/Time']).dt.time
df_c.head()
# Out:
# D:\Python\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,1,2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-5-d014718606f7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['Create Date/Time']=new_df['Create Date/Time']
# <ipython-input-5-d014718606f7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['Time']=pd.to_datetime(df_c['Create Date/Time']).dt.time
#   District         Event Circle Police Station Caller Source  \
# 0  LUCKNOW  P01042100004     C1            PS1         PHONE
# 1  LUCKNOW  P01042104316     C1            PS1         PHONE
# 2  LUCKNOW  P01042104847     C1            PS1         PHONE
# 3  LUCKNOW  P01042105074     C1            PS1         PHONE
# 4  LUCKNOW  P01042105152     C1            PS1         PHONE
#
#                    Event Type       Event Sub-Type     Create Date/Time  \
# 0  Information Against Police   Misbehavior By Prv  01-04-2021 00:00:00
# 1            Threat In Person               Attack  01-04-2021 12:09:00
# 2                     Dispute  Dispute In Hospital  01-04-2021 12:51:00
# 3                    Gambling           Play Cards  01-04-2021 13:10:00
# 4            Threat In Person               Attack  01-04-2021 13:18:00
#
#    Latitude  Longitude                 day      Time
# 0    26.834     81.008 2021-04-01 00:00:00  00:00:00
# 1    26.828     81.014 2021-04-01 12:09:00  12:09:00
# 2    26.840     81.009 2021-04-01 12:51:00  12:51:00
# 3    26.828     81.002 2021-04-01 13:10:00  13:10:00
# 4    26.834     81.033 2021-04-01 13:18:00  13:18:00

# %%
# reading date,month and year values from the date and storing in Prop_date column
df_c['Prop_date']=(df_c['day']).dt.strftime('%d/%m/%Y')
df_c.head()
# Out:
# <ipython-input-6-8b41b9e19812>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['Prop_date']=(df_c['day']).dt.strftime('%d/%m/%Y')
#   District         Event Circle Police Station Caller Source  \
# 0  LUCKNOW  P01042100004     C1            PS1         PHONE
# 1  LUCKNOW  P01042104316     C1            PS1         PHONE
# 2  LUCKNOW  P01042104847     C1            PS1         PHONE
# 3  LUCKNOW  P01042105074     C1            PS1         PHONE
# 4  LUCKNOW  P01042105152     C1            PS1         PHONE
#
#                    Event Type       Event Sub-Type     Create Date/Time  \
# 0  Information Against Police   Misbehavior By Prv  01-04-2021 00:00:00
# 1            Threat In Person               Attack  01-04-2021 12:09:00
# 2                     Dispute  Dispute In Hospital  01-04-2021 12:51:00
# 3                    Gambling           Play Cards  01-04-2021 13:10:00
# 4            Threat In Person               Attack  01-04-2021 13:18:00
#
#    Latitude  Longitude                 day      Time   Prop_date
# 0    26.834     81.008 2021-04-01 00:00:00  00:00:00  01/04/2021
# 1    26.828     81.014 2021-04-01 12:09:00  12:09:00  01/04/2021
# 2    26.840     81.009 2021-04-01 12:51:00  12:51:00  01/04/2021
# 3    26.828     81.002 2021-04-01 13:10:00  13:10:00  01/04/2021
# 4    26.834     81.033 2021-04-01 13:18:00  13:18:00  01/04/2021

# %%
# getting month of the crime from data
month = pd.to_datetime(df_c['Prop_date'],dayfirst=True).dt.strftime('%m')
month
# Out:
# 0       04
# 1       04
# 2       04
# 3       04
# 4       04
#         ..
# 5123    06
# 5124    06
# 5125    06
# 5126    06
# 5127    06
# Name: Prop_date, Length: 5123, dtype: object

# %%
# creating a column to store the month and storing the details
df_c['month']=month
df_c.head()
# Out:
# <ipython-input-8-3f49a414c645>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['month']=month
#   District         Event Circle Police Station Caller Source  \
# 0  LUCKNOW  P01042100004     C1            PS1         PHONE
# 1  LUCKNOW  P01042104316     C1            PS1         PHONE
# 2  LUCKNOW  P01042104847     C1            PS1         PHONE
# 3  LUCKNOW  P01042105074     C1            PS1         PHONE
# 4  LUCKNOW  P01042105152     C1            PS1         PHONE
#
#                    Event Type       Event Sub-Type     Create Date/Time  \
# 0  Information Against Police   Misbehavior By Prv  01-04-2021 00:00:00
# 1            Threat In Person               Attack  01-04-2021 12:09:00
# 2                     Dispute  Dispute In Hospital  01-04-2021 12:51:00
# 3                    Gambling           Play Cards  01-04-2021 13:10:00
# 4            Threat In Person               Attack  01-04-2021 13:18:00
#
#    Latitude  Longitude                 day      Time   Prop_date month
# 0    26.834     81.008 2021-04-01 00:00:00  00:00:00  01/04/2021    04
# 1    26.828     81.014 2021-04-01 12:09:00  12:09:00  01/04/2021    04
# 2    26.840     81.009 2021-04-01 12:51:00  12:51:00  01/04/2021    04
# 3    26.828     81.002 2021-04-01 13:10:00  13:10:00  01/04/2021    04
# 4    26.834     81.033 2021-04-01 13:18:00  13:18:00  01/04/2021    04

# %%
x = df_c.drop(columns=['District', 'Event', 'Circle', 'Police Station', 'Caller Source', 'Event Sub-Type'])
x
# Out:
#                       Event Type     Create Date/Time  Latitude  Longitude  \
# 0     Information Against Police  01-04-2021 00:00:00    26.834     81.008
# 1               Threat In Person  01-04-2021 12:09:00    26.828     81.014
# 2                        Dispute  01-04-2021 12:51:00    26.840     81.009
# 3                       Gambling  01-04-2021 13:10:00    26.828     81.002
# 4               Threat In Person  01-04-2021 13:18:00    26.834     81.033
# ...                          ...                  ...       ...        ...
# 5123                     Dispute  30-06-2021 17:59:54    26.866     81.026
# 5124                     Dispute  30-06-2021 18:01:05    26.864     81.006
# 5125                Cyber Crimes  30-06-2021 18:10:59    26.864     80.998
# 5126                     Robbery  30-06-2021 18:33:39    26.873     81.023
# 5127            Threat In Person  30-06-2021 23:59:08    26.863     81.001
#
#                      day      Time   Prop_date month
# 0    2021-04-01 00:00:00  00:00:00  01/04/2021    04
# 1    2021-04-01 12:09:00  12:09:00  01/04/2021    04
# 2    2021-04-01 12:51:00  12:51:00  01/04/2021    04
# 3    2021-04-01 13:10:00  13:10:00  01/04/2021    04
# 4    2021-04-01 13:18:00  13:18:00  01/04/2021    04
# ...                  ...       ...         ...   ...
# 5123 2021-06-30 17:59:54  17:59:54  30/06/2021    06
# 5124 2021-06-30 18:01:05  18:01:05  30/06/2021    06
# 5125 2021-06-30 18:10:59  18:10:59  30/06/2021    06
# 5126 2021-06-30 18:33:39  18:33:39  30/06/2021    06
# 5127 2021-06-30 23:59:08  23:59:08  30/06/2021    06
#
# [5123 rows x 8 columns]

# %%
x2 = df_c['Event Type']
x2
# Out:
# 0       Information Against Police
# 1                 Threat In Person
# 2                          Dispute
# 3                         Gambling
# 4                 Threat In Person
#                    ...
# 5123                       Dispute
# 5124                       Dispute
# 5125                  Cyber Crimes
# 5126                       Robbery
# 5127              Threat In Person
# Name: Event Type, Length: 5123, dtype: object

# %%
df2 = x.sort_values(by=['Event Type'])
df2
# Out:
#      Event Type     Create Date/Time  Latitude  Longitude                 day  \
# 3457   Accident  23-05-2021 21:45:36    26.865     81.037 2021-05-23 21:45:36
# 4286   Accident  27-06-2021 20:54:12    26.877     81.010 2021-06-27 20:54:12
# 890    Accident  11-04-2021 20:00:00    26.847     80.987 2021-04-11 20:00:00
# 1193   Accident  30-04-2021 21:46:00    26.846     81.012 2021-04-30 21:46:00
# 3855   Accident  09-06-2021 00:59:13    26.893     81.073 2021-06-09 00:59:13
# ...         ...                  ...       ...        ...                 ...
# 3613    Unknown  31-05-2021 07:50:50    26.850     81.023 2021-05-31 07:50:50
# 311     Unknown  12-05-2021 21:18:17    26.846     81.061 2021-05-12 21:18:17
# 1032    Unknown  20-04-2021 10:17:00    26.846     80.998 2021-04-20 10:17:00
# 2459    Unknown  16-04-2021 22:52:00    26.872     81.028 2021-04-16 22:52:00
# 788     Unknown  06-04-2021 21:35:00    26.847     80.993 2021-04-06 21:35:00
#
#           Time   Prop_date month
# 3457  21:45:36  23/05/2021    05
# 4286  20:54:12  27/06/2021    06
# 890   20:00:00  11/04/2021    04
# 1193  21:46:00  30/04/2021    04
# 3855  00:59:13  09/06/2021    06
# ...        ...         ...   ...
# 3613  07:50:50  31/05/2021    05
# 311   21:18:17  12/05/2021    05
# 1032  10:17:00  20/04/2021    04
# 2459  22:52:00  16/04/2021    04
# 788   21:35:00  06/04/2021    04
#
# [5123 rows x 8 columns]

# %%
df_ = x.drop(columns=['Latitude', 'Longitude', 'day', 'Time', 'Prop_date', 'month'])
df_
# Out:
#                       Event Type     Create Date/Time
# 0     Information Against Police  01-04-2021 00:00:00
# 1               Threat In Person  01-04-2021 12:09:00
# 2                        Dispute  01-04-2021 12:51:00
# 3                       Gambling  01-04-2021 13:10:00
# 4               Threat In Person  01-04-2021 13:18:00
# ...                          ...                  ...
# 5123                     Dispute  30-06-2021 17:59:54
# 5124                     Dispute  30-06-2021 18:01:05
# 5125                Cyber Crimes  30-06-2021 18:10:59
# 5126                     Robbery  30-06-2021 18:33:39
# 5127            Threat In Person  30-06-2021 23:59:08
#
# [5123 rows x 2 columns]

# %%
count1 = df_.groupby(['Event Type']).count()
print(count1)
# Out:
#                                                     Create Date/Time
# Event Type
# Accident                                                          17
# Accident Explosive                                                 1
# Animals Related                                                   62
# Animals Smugling                                                   1
# Assault/Riot/Commotion                                             5
# Attempted Murder                                                  26
# Child Crime                                                        7
# Child Crime(Sexual Abuse)                                          7
# Corona                                                           415
# Crime On Phone Mobile Social Media Internet                      130
# Cyber Crimes                                                      53
# Dacoity                                                            9
# Differently Abled People                                          15
# Dispute                                                         1549
# Domestic Violence                                                596
# Dowry Related Crime                                                1
# Election Offences-Violation Of Model Code Of Co...                 9
# Encroachment                                                      34
# Escort For Safety                                                  1
# Excise Act Offenses                                               13
# Female Harrassment                                                43
# Female Sexual Harrassment                                         75
# Forgery                                                            8
# Found Deadbody                                                    32
# Gambling                                                          54
# Human Trafficking                                                  2
# Illegal Mining                                                     8
# Information Against Other Government Departments                  27
# Information Against Police                                       167
# Kidnap                                                            24
# Major Fire                                                         1
# Medium Fire                                                       53
# Missing                                                          101
# Murder                                                             1
# Ndps Act Offenses                                                  7
# Personally Threat                                                  1
# Pick Pocket                                                        2
# Police Help Required By 108                                        6
# Police Help Required By 1090                                       5
# Pollution                                                         44
# Property Disputes                                                128
# Robbery                                                           71
# Small Fire                                                         6
# Sos                                                               36
# Suicide                                                           10
# Suicide Attempt                                                    1
# Suspicious Object Information                                      5
# Suspicious Person Information                                     29
# Theft                                                            339
# Threat In Person                                                 578
# Threat On Phone Email Social Media                                 3
# Traffic Jam                                                       25
# Unclaimed Information                                             89
# Unknown                                                          191

# %%
count1.rename(columns = {'Event Type':'Event type', 
                       'Create Date/Time':'No. of crimes'}, 
            inplace = True)
print(count1)
# Out:
#                                                     No. of crimes
# Event Type
# Accident                                                       17
# Accident Explosive                                              1
# Animals Related                                                62
# Animals Smugling                                                1
# Assault/Riot/Commotion                                          5
# Attempted Murder                                               26
# Child Crime                                                     7
# Child Crime(Sexual Abuse)                                       7
# Corona                                                        415
# Crime On Phone Mobile Social Media Internet                   130
# Cyber Crimes                                                   53
# Dacoity                                                         9
# Differently Abled People                                       15
# Dispute                                                      1549
# Domestic Violence                                             596
# Dowry Related Crime                                             1
# Election Offences-Violation Of Model Code Of Co...              9
# Encroachment                                                   34
# Escort For Safety                                               1
# Excise Act Offenses                                            13
# Female Harrassment                                             43
# Female Sexual Harrassment                                      75
# Forgery                                                         8
# Found Deadbody                                                 32
# Gambling                                                       54
# Human Trafficking                                               2
# Illegal Mining                                                  8
# Information Against Other Government Departments               27
# Information Against Police                                    167
# Kidnap                                                         24
# Major Fire                                                      1
# Medium Fire                                                    53
# Missing                                                       101
# Murder                                                          1
# Ndps Act Offenses                                               7
# Personally Threat                                               1
# Pick Pocket                                                     2
# Police Help Required By 108                                     6
# Police Help Required By 1090                                    5
# Pollution                                                      44
# Property Disputes                                             128
# Robbery                                                        71
# Small Fire                                                      6
# Sos                                                            36
# Suicide                                                        10
# Suicide Attempt                                                 1
# Suspicious Object Information                                   5
# Suspicious Person Information                                  29
# Theft                                                         339
# Threat In Person                                              578
# Threat On Phone Email Social Media                              3
# Traffic Jam                                                    25
# Unclaimed Information                                          89
# Unknown                                                       191

# %%
s = count1.plot.bar(figsize=(20,8))
s;

# %%
s2 = count1.plot.line(figsize=(20,8))
s2;

# %%
x3 = x.drop(columns=['Create Date/Time', 'day'])
x3
# Out:
#                       Event Type  Latitude  Longitude      Time   Prop_date  \
# 0     Information Against Police    26.834     81.008  00:00:00  01/04/2021
# 1               Threat In Person    26.828     81.014  12:09:00  01/04/2021
# 2                        Dispute    26.840     81.009  12:51:00  01/04/2021
# 3                       Gambling    26.828     81.002  13:10:00  01/04/2021
# 4               Threat In Person    26.834     81.033  13:18:00  01/04/2021
# ...                          ...       ...        ...       ...         ...
# 5123                     Dispute    26.866     81.026  17:59:54  30/06/2021
# 5124                     Dispute    26.864     81.006  18:01:05  30/06/2021
# 5125                Cyber Crimes    26.864     80.998  18:10:59  30/06/2021
# 5126                     Robbery    26.873     81.023  18:33:39  30/06/2021
# 5127            Threat In Person    26.863     81.001  23:59:08  30/06/2021
#
#      month
# 0       04
# 1       04
# 2       04
# 3       04
# 4       04
# ...    ...
# 5123    06
# 5124    06
# 5125    06
# 5126    06
# 5127    06
#
# [5123 rows x 6 columns]

# %%
x4 = x3.drop(columns=['Latitude', 'Longitude', 'Prop_date', 'Time'])
x4
# Out:
#                       Event Type month
# 0     Information Against Police    04
# 1               Threat In Person    04
# 2                        Dispute    04
# 3                       Gambling    04
# 4               Threat In Person    04
# ...                          ...   ...
# 5123                     Dispute    06
# 5124                     Dispute    06
# 5125                Cyber Crimes    06
# 5126                     Robbery    06
# 5127            Threat In Person    06
#
# [5123 rows x 2 columns]

# %%
count4 = x4.groupby(['month']).count()
print(count4)
# Out:
#        Event Type
# month
# 04           2070
# 05           1434
# 06           1619

# %%
count4.rename(columns = {'month':'Month', 
                       'Event Type':'No. of crimes'}, 
            inplace = True)
print(count4)
# Out:
#        No. of crimes
# month
# 04              2070
# 05              1434
# 06              1619

# %%
count4.index = ['April', 'May', 'June']
count4
# Out:
#        No. of crimes
# April           2070
# May             1434
# June            1619

# %%
g = count4.plot.bar(figsize=(10,8))
g;

# %%
g2 = count4.plot.pie(subplots=True, figsize=(15, 10))
g2;

# %%
import seaborn as sns

# %%
plt.style.use('seaborn')
top_5_crimes = x3['Event Type'].value_counts().sort_values(ascending=False).head()
temp = x3.groupby('Event Type', as_index=False).agg({"month": "count"})
temp = temp.sort_values(by=['month'], ascending=False).head()
temp = temp.sort_values(by='month', ascending=True)
sns.barplot(x='month', y='Event Type', data=temp, palette="mako")
plt.title("Top 5 Crimes in Lucknow", fontdict = {'fontsize': 30, 'fontname':'Arial', 'color': '#000000'})
plt.xlabel("\nCOUNT OF CRIMES", fontdict = {'fontsize': 15})
plt.ylabel("")
plt.xticks(rotation=90)
plt.show()

# %%
def hour(x):
    return x.strftime("%H")
x3['Hour_Day'] = x3['Time'].apply(hour)

# %%
test = x3.sort_values(by=['Hour_Day'])
test['Hour_Day']
# Out:
# 0       00
# 3250    00
# 3218    00
# 3196    00
# 3195    00
#         ..
# 1663    23
# 1662    23
# 65      23
# 2560    23
# 5127    23
# Name: Hour_Day, Length: 5123, dtype: object

# %%
plt.style.use('seaborn-dark')
sns.set_context('paper')
fig, ax = plt.subplots(figsize=(10, 5))
sns.countplot(x='Hour_Day', data=test, palette="rocket")
plt.title("Crimes in Lucknow based on time", fontdict={'fontsize': 40, 'color': '#bb0e14','fontname':'Agency FB'}, weight="bold")
plt.xlabel("\nHour in the Day", fontdict={'fontsize': 15}, weight='bold')
plt.ylabel("Number of Crimes\n", fontdict={'fontsize': 15}, weight="bold")
plt.show()

# %%
dispute_df = x3[x3['Event Type']=='Dispute']
hours = [int(x) for x in list(dispute_df['Hour_Day'].unique())]
hours = sorted(hours)
dis = list(dispute_df['Hour_Day'].value_counts().sort_index())
fig, ax = plt.subplots(figsize=(10, 5))
sns.barplot(x=hours, y=dis, palette='inferno')
plt.title("Disputes over a day", fontdict={'fontsize': 40, 'color': '#bb0e14','fontname':'Agency FB'}, weight="bold")
plt.xlabel("\nHour in the Day", fontdict={'fontsize': 15}, weight='bold')
plt.ylabel("Number of Crimes\n", fontdict={'fontsize': 15}, weight="bold")
plt.show()

# %%
import folium

# %%
my_map = folium.Map()
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7fa84c04842c492c9cbcf9ab141eaf36%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7fa84c04842c492c9cbcf9ab141eaf36%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7fa84c04842c492c9cbcf9ab141eaf36%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7fa84c04842c492c9cbcf9ab141eaf36%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
#my_map = folium.Map(location=[26.850000, 80.949997], zoom_start=14, prefer_canvas=True, min_zoom=11, max_zoom=16)
#for _, l in x3.iterrows():
#    folium.Marker(location=[l['Latitude'], l['Longitude']], popup=[l['Latitude'], l['Longitude']]).add_to(my_map)
#my_map

# %%
my_map = folium.Map(location=[26.850000, 80.949997], zoom_start=14, prefer_canvas=True, min_zoom=11, max_zoom=16)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_817f87391fea4f07858ac9c3a3aedd39%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_817f87391fea4f07858ac9c3a3aedd39%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_817f87391fea4f07858ac9c3a3aedd39%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_817f87391fea4f07858ac9c3a3aedd39%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B26.85%2C%2080.949997%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
